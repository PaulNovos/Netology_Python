# %% [markdown]
# # Задание 1
# Скачайте с сайта grouplens.org...movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
import pandas as pd

ratings = pd.read_csv('ratings.csv')

ratings[(ratings.rating == 5)].movieId.value_counts().head()

# %% [markdown]
# # Задание 2
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
data_power = pd.read_csv('power.csv')

data_power.query('2005 <= year <= 2010').query('category in [4, 12, 21]').query("country in ['Lithuania', 'Latvia', 'Estonia']").query('quantity > 0')['quantity'].sum()
# Out:
# 240580.0

# %% [markdown]
# # Задание 3
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.

# %%
df = pd.read_html('https://www.finam.ru/')

df[0]
# Out:
#                    0                  1       2
# 0   ФосАгро ао 3.36%     Мечел ап-6.99%     NaN
# 1         ФосАгро ао                NaN   3.36%
# 2           Мечел ап                NaN  -6.99%
# 3    АЛРОСА ао 2.93%     Мечел ао-4.53%     NaN
# 4          АЛРОСА ао                NaN   2.93%
# 5           Мечел ао                NaN  -4.53%
# 6   +МосЭнерго 2.83%     iИСКЧ ао-3.51%     NaN
# 7         +МосЭнерго                NaN   2.83%
# 8           iИСКЧ ао                NaN  -3.51%
# 9      РУСАЛ ао2.78%      ЛСР ао -2.97%     NaN
# 10          РУСАЛ ао                NaN   2.78%
# 11            ЛСР ао                NaN  -2.97%
# 12    Petropavl2.59%      ЛУКОЙЛ -2.44%     NaN
# 13         Petropavl                NaN   2.59%
# 14            ЛУКОЙЛ                NaN  -2.44%
# 15      НКНХ ап2.44%      TCS-гдр-1.68%     NaN
# 16           НКНХ ап                NaN   2.44%
# 17           TCS-гдр                NaN  -1.68%
# 18    MAIL-гдр 2.06%     FIVE-гдр-1.66%     NaN
# ...
